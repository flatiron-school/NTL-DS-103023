# %% [markdown]
# ![sql](images/sql-logo.jpg)

# %%
import pandas as pd
import sqlite3
import pandasql

conn = sqlite3.connect('data/flights.db')
cur = conn.cursor()

# %% [markdown]
# # Objectives

# %% [markdown]
# - Use SQL aggregation functions with GROUP BY
# - Use HAVING for group filtering
# - Use SQL JOIN to combine tables using keys

# %% [markdown]
# # Aggregating Functions

# %% [markdown]
# >  A SQL **aggregating function** takes in many values and returns one value.

# %% [markdown]
# We have already seen some SQL aggregating functions like `COUNT()`. There are also others, like SUM(), AVG(), MIN(), and MAX().

# %% [markdown]
# ## Example Simple Aggregations

# %%
# Max value for longitude
pd.read_sql('''
    
SELECT MAX(CAST(longitude as real)) AS max_longitude
FROM airports
    
''', conn)
# Out:
#    max_longitude
# 0        179.951

# %%
# Max value for id in table
pd.read_sql('''
SELECT 
    MAX(CAST(id AS integer))
FROM 
    airports
''', conn)
# Out:
#    MAX(CAST(id AS integer))
# 0                      9541

# %%
# Effectively counts all the inactive airlines 
pd.read_sql('''
    SELECT 
        COUNT()
    FROM 
        airlines
    WHERE 
        active='N'
''', conn)
# Out:
#    COUNT()
# 0     4886

# %% [markdown]
# We can also give aliases to our aggregations:

# %%
# Effectively counts all the active airlines 
pd.read_sql('''
    SELECT 
        COUNT() AS number_of_active_airlines
    FROM 
        airlines
    WHERE 
        active='Y'
''', conn)
# Out:
#    number_of_active_airlines
# 0                       1161

# %% [markdown]
# # Grouping in SQL

# %% [markdown]
# We can go deeper and use aggregation functions on _groups_ using the `GROUP BY` clause.

# %% [markdown]
# The `GROUP BY` clause will group one or more columns together with the same values as one group to perform aggregation functions on.

# %% [markdown]
# ## Example `GROUP BY`  Statements

# %% [markdown]
# Let's say we want to know how many active and non-active airlines there are.

# %% [markdown]
# ### Without `GROUP BY`

# %% [markdown]
# Let's first start with just seeing how many airlines there are:

# %%
df_results = pd.read_sql('''

SELECT COUNT() AS num_of_airlines
FROM airlines
''', conn)

df_results
# Out:
#    num_of_airlines
# 0             6048

# %% [markdown]
# One way for us to get the counts for each is to create two queries that will filter each kind of airline (active vs non-active) and count those values:

# %%
df_active = pd.read_sql('''
    SELECT 
        COUNT() AS number_of_active_airlines
    FROM 
        airlines
    WHERE 
        active='Y'
''', conn)

df_inactive = pd.read_sql('''
    SELECT 
        COUNT() AS number_of_inactive_airlines
    FROM 
        airlines
    WHERE 
        active='N'
''', conn)

display(df_active)
display(df_inactive)
# Out:
#    number_of_active_airlines
# 0                       1161
#    number_of_inactive_airlines
# 0                         4886

# %% [markdown]
# This works but it's inefficient.

# %% [markdown]
# ### With `GROUP BY`

# %% [markdown]
# Instead, we can tell the SQL server to do the work for us by grouping values we care about for us!

# %%
df_results = pd.read_sql('''

SELECT COUNT() as num_of_airlines, active
FROM airlines
GROUP BY active

''', conn)

df_results
# Out:
#    num_of_airlines active
# 0             4886      N
# 1             1161      Y
# 2                1      n

# %% [markdown]
# This is great! And if you look closely, you can observe we have _three_ different groups instead of our expected two!

# %% [markdown]
# ## Group Task

# %% [markdown]
# - Which countries have the highest numbers of active airlines? Return the top 10.

# %%
# Note that we have a 'country' field/column
pd.read_sql('''
    SELECT
        *
    FROM
        airlines
''', conn).head()
# Out:
#    index id                                          name alias  iata  icao  \
# 0      0  1                                Private flight    \N     -  None
# 1      1  2                                   135 Airways    \N  None   GNL
# 2      2  3                                 1Time Airline    \N    1T   RNX
# 3      3  4  2 Sqn No 1 Elementary Flying Training School    \N  None   WYT
# 4      4  5                               213 Flight Unit    \N  None   TFU
#
#   callsign         country active
# 0     None            None      Y
# 1  GENERAL   United States      N
# 2  NEXTIME    South Africa      Y
# 3     None  United Kingdom      N
# 4     None          Russia      N

# %%
pd.read_sql("""

SELECT country, COUNT() AS num_airlines
FROM airlines
WHERE active = "Y"
GROUP BY country
ORDER BY num_airlines DESC
LIMIT 10

""", conn)
# Out:
#           country  num_airlines
# 0   United States           141
# 1          Russia            72
# 2  United Kingdom            40
# 3         Germany            37
# 4          Canada            34
# 5       Australia            26
# 6           China            25
# 7           Spain            24
# 8          Brazil            23
# 9          France            22

# %%
pandas_way = pd.read_sql("""
SELECT *
FROM airlines


""", conn)

# %%
pandas_way
# Out:
#       index     id                                          name  \
# 0         0      1                                Private flight
# 1         1      2                                   135 Airways
# 2         2      3                                 1Time Airline
# 3         3      4  2 Sqn No 1 Elementary Flying Training School
# 4         4      5                               213 Flight Unit
# ...     ...    ...                                           ...
# 6043   6043  19828                                    Vuela Cuba
# 6044   6044  19830                                 All Australia
# 6045   6045  19831                                    Fly Europa
# 6046   6046  19834                                   FlyPortugal
# 6047   6047  19845                          FTI Fluggesellschaft
#
#               alias  iata  icao     callsign         country active
# 0                \N     -  None         None            None      Y
# 1                \N  None   GNL      GENERAL   United States      N
# 2                \N    1T   RNX      NEXTIME    South Africa      Y
# 3                \N  None   WYT         None  United Kingdom      N
# 4                \N  None   TFU         None          Russia      N
# ...             ...   ...   ...          ...             ...    ...
# 6043     Vuela Cuba    6C   6CC         None            Cuba      Y
# 6044  All Australia    88   8K8         None       Australia      Y
# 6045           None    ER   RWW         None           Spain      Y
# 6046           None    PO   FPT  FlyPortugal        Portugal      Y
# 6047           None  None   FTI         None         Germany      N
#
# [6048 rows x 9 columns]

# %%
pandas_way.loc[pandas_way['active'] == 'Y']['country'].value_counts()[:10]
# Out:
# United States     141
# Russia             72
# United Kingdom     40
# Germany            37
# Canada             34
# Australia          26
# China              25
# Spain              24
# Brazil             23
# France             22
# Name: country, dtype: int64

# %% [markdown]
# <details>
#     <summary><b>Possible Solution</b></summary>
#
# ``` sql
#     pd.read_sql('''
#     SELECT
#         COUNT() AS num,
#         country
#     FROM
#         airlines
#     WHERE
#         active='Y'
#     GROUP BY
#         country
#     ORDER BY
#         num DESC
#     LIMIT 10
#     ''', conn)```
# </details>

# %% [markdown]
# > Note that the `GROUP BY` clause is considered _before_ the `ORDER BY` and `LIMIT` clauses, more on this later.

# %% [markdown]
# ## Exercise: Grouping

# %% [markdown]
# - Run a query that will return the number of airports by time zone. Each row should have a number of airports and a time zone.

# %%
# Your code here
pd.read_sql("""
SELECT *
FROM airports
LIMIT 5
""", conn)
# Out:
#    index id                        name          city           country code  \
# 0      0  1                      Goroka        Goroka  Papua New Guinea  GKA
# 1      1  2                      Madang        Madang  Papua New Guinea  MAG
# 2      2  3                 Mount Hagen   Mount Hagen  Papua New Guinea  HGU
# 3      3  4                      Nadzab        Nadzab  Papua New Guinea  LAE
# 4      4  5  Port Moresby Jacksons Intl  Port Moresby  Papua New Guinea  POM
#
#    icao   latitude   longitude altitude offset dst              timezone
# 0  AYGA  -6.081689  145.391881     5282     10   U  Pacific/Port_Moresby
# 1  AYMD  -5.207083    145.7887       20     10   U  Pacific/Port_Moresby
# 2  AYMH  -5.826789  144.295861     5388     10   U  Pacific/Port_Moresby
# 3  AYNZ  -6.569828  146.726242      239     10   U  Pacific/Port_Moresby
# 4  AYPY  -9.443383   147.22005      146     10   U  Pacific/Port_Moresby

# %%
pd.read_sql("""

SELECT timezone, COUNT() AS num_airports, AVG(CAST(altitude AS int)) AS average_alt
FROM airports
GROUP BY timezone
ORDER BY num_airports DESC


""", conn)
# Out:
#               timezone  num_airports  average_alt
# 0     America/New_York           628   471.812102
# 1      America/Chicago           373   804.284182
# 2        Europe/Berlin           319   596.109718
# 3    America/Anchorage           258   229.236434
# 4         Europe/Paris           232   632.025862
# ..                 ...           ...          ...
# 289   America/Anguilla             1   127.000000
# 290  Africa/Porto-Novo             1    19.000000
# 291     Africa/Mbabane             1  2075.000000
# 292   Africa/Bujumbura             1  2582.000000
# 293      Africa/Banjul             1    95.000000
#
# [294 rows x 3 columns]

# %% [markdown]
# <details>
#     <summary><b>Possible Solution</b></summary>
#
# ``` sql
# pd.read_sql('''
#     SELECT
#         airports.timezone
#         ,COUNT() AS num_of_airports
#     FROM
#         airports
#     GROUP BY
#         airports.timezone
#     ORDER BY
#         num_of_airports DESC
# ''', conn) ```
# </details>

# %% [markdown]
# # Filtering Groups with `HAVING`

# %% [markdown]
# We showed that you can filter tables with `WHERE`. We can similarly filter _groups/aggregations_ using `HAVING` clauses.

# %% [markdown]
# ## Examples of Using `HAVING`

# %% [markdown]
# ### Simple Filtering - Number of Airports in a Country

# %% [markdown]
# Let's come back to the aggregation of active airlines:

# %%
pd.read_sql('''
    SELECT 
        COUNT() AS num,
        country
    FROM 
        airlines
    WHERE 
        active='Y'
    GROUP BY 
        country
    ORDER BY 
        num DESC
''', conn)
# Out:
#      num              country
# 0    141        United States
# 1     72               Russia
# 2     40       United Kingdom
# 3     37              Germany
# 4     34               Canada
# ..   ...                  ...
# 190    1  Antigua and Barbuda
# 191    1       American Samoa
# 192    1              AVIANCA
# 193    1               ALASKA
# 194    1                 S.A.
#
# [195 rows x 2 columns]

# %% [markdown]
# We can see we have a lot of results. But maybe we only want to keep the countries that have more than $30$ active airlines:

# %%
pd.read_sql('''
    SELECT 
        country,
        COUNT() AS num
    FROM 
        airlines
    WHERE 
        active='Y'
    GROUP BY 
        country
    HAVING 
        num > 30
    ORDER BY 
        num DESC
''', conn)
# Out:
#           country  num
# 0   United States  141
# 1          Russia   72
# 2  United Kingdom   40
# 3         Germany   37
# 4          Canada   34

# %%
pd.read_sql('''
    SELECT 
        country,
        COUNT() AS num
    FROM 
        airlines
    WHERE 
        active='Y' AND num > 30
    GROUP BY 
        country
    ORDER BY 
        num DESC
''', conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: misuse of aggregate: COUNT()
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-39-1c79c2d3e5a9> in <module>
# ----> 1 pd.read_sql('''
#       2     SELECT
#       3         country,
#       4         COUNT() AS num
#       5     FROM
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql '
#     SELECT
#         country,
#         COUNT() AS num
#     FROM
#         airlines
#     WHERE
#         active='Y' AND num > 30
#     GROUP BY
#         country
#     ORDER BY
#         num DESC
# ': misuse of aggregate: COUNT()

# %% [markdown]
# ## Filtering Different Aggregations - Airport Altitudes

# %% [markdown]
# We can also filter on other aggregations. For example, let's say we want to investigate the `airports` table.

# %% [markdown]
# Specifically, we want to know the height of the _highest airport_ in a country given that it has _at least $100$ airports_.

# %% [markdown]
# ### Looking at the `airports` Table

# %%
df_airports = pd.read_sql('''
    SELECT 
        *
    FROM 
        airports 
''', conn)

df_airports.head()
# Out:
#    index id                        name          city           country code  \
# 0      0  1                      Goroka        Goroka  Papua New Guinea  GKA
# 1      1  2                      Madang        Madang  Papua New Guinea  MAG
# 2      2  3                 Mount Hagen   Mount Hagen  Papua New Guinea  HGU
# 3      3  4                      Nadzab        Nadzab  Papua New Guinea  LAE
# 4      4  5  Port Moresby Jacksons Intl  Port Moresby  Papua New Guinea  POM
#
#    icao   latitude   longitude altitude offset dst              timezone
# 0  AYGA  -6.081689  145.391881     5282     10   U  Pacific/Port_Moresby
# 1  AYMD  -5.207083    145.7887       20     10   U  Pacific/Port_Moresby
# 2  AYMH  -5.826789  144.295861     5388     10   U  Pacific/Port_Moresby
# 3  AYNZ  -6.569828  146.726242      239     10   U  Pacific/Port_Moresby
# 4  AYPY  -9.443383   147.22005      146     10   U  Pacific/Port_Moresby

# %% [markdown]
# ### Looking at the Highest Airport

# %% [markdown]
# Let's first get the highest altitude for each country:

# %%
pd.read_sql('''
   
SELECT country, MAX(CAST(altitude as real)) AS max_altitude
FROM airports
GROUP BY country
ORDER BY country

   
''', conn)
# Out:
#             country  max_altitude
# 0       Afghanistan        7400.0
# 1           Albania         126.0
# 2           Algeria        4518.0
# 3    American Samoa         110.0
# 4            Angola        5778.0
# ..              ...           ...
# 235       West Bank        2485.0
# 236  Western Sahara         350.0
# 237           Yemen        7216.0
# 238          Zambia        4636.0
# 239        Zimbabwe        4887.0
#
# [240 rows x 2 columns]

# %% [markdown]
# ### Looking at the Number of Airports Too

# %% [markdown]
# We can also get the number of airports for each country.

# %%
pd.read_sql('''

SELECT country, MAX(CAST(altitude as real)) AS max_altitude, COUNT() AS num_airports
FROM airports
GROUP BY country
ORDER BY country

''', conn)
# Out:
#             country  max_altitude  num_airports
# 0       Afghanistan        7400.0            21
# 1           Albania         126.0             1
# 2           Algeria        4518.0            44
# 3    American Samoa         110.0             3
# 4            Angola        5778.0            26
# ..              ...           ...           ...
# 235       West Bank        2485.0             1
# 236  Western Sahara         350.0             3
# 237           Yemen        7216.0            11
# 238          Zambia        4636.0            13
# 239        Zimbabwe        4887.0            16
#
# [240 rows x 3 columns]

# %% [markdown]
# ### Filtering on Aggregations

# %% [markdown]
# > Recall:
# >
# > We want to know the height of the _highest airport_ in a country given that it has _at least $100$ airports_.

# %%
pd.read_sql('''

SELECT country, MAX(CAST(altitude as real)) AS max_altitude
FROM airports
GROUP BY country
HAVING COUNT() >= 100
ORDER BY country


''', conn)
# Out:
#            country  max_altitude
# 0        Argentina       11414.0
# 1        Australia        4260.0
# 2           Brazil        8708.0
# 3           Canada        3939.0
# 4            China       14472.0
# 5           France        6588.0
# 6          Germany        2297.0
# 7            India       10682.0
# 8        Indonesia        9104.0
# 9            Japan        2200.0
# 10          Russia       13411.0
# 11    South Africa        5700.0
# 12  United Kingdom         811.0
# 13   United States        9308.0

# %% [markdown]
# # Joins

# %% [markdown]
# The biggest advantage in using a relational database (like we've been with SQL) is that you can create **joins**.

# %% [markdown]
# > By using **`JOIN`** in our query, we can connect different tables using their _relationships_ to other tables.
# >
# > Usually we use a key (*foreign key*) to tell us how the two tables are related.

# %% [markdown]
# There are different types of joins and each has their different use case. This is very similair to pandas `.join(), .merge()` as well as tableau relationships.

# %% [markdown]
# ## `INNER JOIN`

# %% [markdown]
# > An **inner join** will join two tables together and only keep rows if the _key is in both tables_

# %% [markdown]
# ![](images/inner_join.png)

# %% [markdown]
# Example of an inner join:
#
# ```sql
# SELECT
#     table1.column_name,
#     table2.different_column_name
# FROM
#     table1
#     INNER JOIN table2
#         ON table1.shared_column_name = table2.shared_column_name
# ```

# %% [markdown]
# ### Code Example for Inner Joins

# %% [markdown]
# Let's say we want to look at the different airplane routes

# %%
pd.read_sql('''
    SELECT 
        *
    FROM
        routes 
''', conn)
# Out:
#        index airline airline_id source source_id dest dest_id codeshare stops  \
# 0          0      2B        410    AER      2965  KZN    2990      None     0
# 1          1      2B        410    ASF      2966  KZN    2990      None     0
# 2          2      2B        410    ASF      2966  MRV    2962      None     0
# 3          3      2B        410    CEK      2968  KZN    2990      None     0
# 4          4      2B        410    CEK      2968  OVB    4078      None     0
# ...      ...     ...        ...    ...       ...  ...     ...       ...   ...
# 67658  67658      ZL       4178    WYA      6334  ADL    3341      None     0
# 67659  67659      ZM      19016    DME      4029  FRU    2912      None     0
# 67660  67660      ZM      19016    FRU      2912  DME    4029      None     0
# 67661  67661      ZM      19016    FRU      2912  OSS    2913      None     0
# 67662  67662      ZM      19016    OSS      2913  FRU    2912      None     0
#
#       equipment
# 0           CR2
# 1           CR2
# 2           CR2
# 3           CR2
# 4           CR2
# ...         ...
# 67658       SF3
# 67659       734
# 67660       734
# 67661       734
# 67662       734
#
# [67663 rows x 10 columns]

# %%
pd.read_sql('''
    SELECT 
        *
    FROM
        airlines 
''', conn)
# Out:
#       index     id                                          name  \
# 0         0      1                                Private flight
# 1         1      2                                   135 Airways
# 2         2      3                                 1Time Airline
# 3         3      4  2 Sqn No 1 Elementary Flying Training School
# 4         4      5                               213 Flight Unit
# ...     ...    ...                                           ...
# 6043   6043  19828                                    Vuela Cuba
# 6044   6044  19830                                 All Australia
# 6045   6045  19831                                    Fly Europa
# 6046   6046  19834                                   FlyPortugal
# 6047   6047  19845                          FTI Fluggesellschaft
#
#               alias  iata  icao     callsign         country active
# 0                \N     -  None         None            None      Y
# 1                \N  None   GNL      GENERAL   United States      N
# 2                \N    1T   RNX      NEXTIME    South Africa      Y
# 3                \N  None   WYT         None  United Kingdom      N
# 4                \N  None   TFU         None          Russia      N
# ...             ...   ...   ...          ...             ...    ...
# 6043     Vuela Cuba    6C   6CC         None            Cuba      Y
# 6044  All Australia    88   8K8         None       Australia      Y
# 6045           None    ER   RWW         None           Spain      Y
# 6046           None    PO   FPT  FlyPortugal        Portugal      Y
# 6047           None  None   FTI         None         Germany      N
#
# [6048 rows x 9 columns]

# %% [markdown]
# This is great but notice the `airline_id` column. It'd be nice to have some more information about the airlines associated with these routes.

# %% [markdown]
# We can do an **inner join** to get this information!

# %% [markdown]
# #### Inner Join Routes & Airline Data

# %%
pd.read_sql('''

SELECT *
FROM routes AS r
    INNER JOIN airlines AS al
        ON r.airline_id = al.id

''', conn)
# Out:
#        index airline airline_id source source_id dest dest_id codeshare stops  \
# 0          0      2B        410    AER      2965  KZN    2990      None     0
# 1          1      2B        410    ASF      2966  KZN    2990      None     0
# 2          2      2B        410    ASF      2966  MRV    2962      None     0
# 3          3      2B        410    CEK      2968  KZN    2990      None     0
# 4          4      2B        410    CEK      2968  OVB    4078      None     0
# ...      ...     ...        ...    ...       ...  ...     ...       ...   ...
# 66980  67658      ZL       4178    WYA      6334  ADL    3341      None     0
# 66981  67659      ZM      19016    DME      4029  FRU    2912      None     0
# 66982  67660      ZM      19016    FRU      2912  DME    4029      None     0
# 66983  67661      ZM      19016    FRU      2912  OSS    2913      None     0
# 66984  67662      ZM      19016    OSS      2913  FRU    2912      None     0
#
#       equipment  index     id              name   alias iata icao    callsign  \
# 0           CR2    409    410        Aerocondor      \N   2B  ARD  AEROCONDOR
# 1           CR2    409    410        Aerocondor      \N   2B  ARD  AEROCONDOR
# 2           CR2    409    410        Aerocondor      \N   2B  ARD  AEROCONDOR
# 3           CR2    409    410        Aerocondor      \N   2B  ARD  AEROCONDOR
# 4           CR2    409    410        Aerocondor      \N   2B  ARD  AEROCONDOR
# ...         ...    ...    ...               ...     ...  ...  ...         ...
# 66980       SF3   4171   4178  Regional Express      \N   ZL  RXA         REX
# 66981       734   5977  19016        Apache Air  Apache   ZM  IWA      APACHE
# 66982       734   5977  19016        Apache Air  Apache   ZM  IWA      APACHE
# 66983       734   5977  19016        Apache Air  Apache   ZM  IWA      APACHE
# 66984       734   5977  19016        Apache Air  Apache   ZM  IWA      APACHE
#
#              country active
# 0           Portugal      Y
# 1           Portugal      Y
# 2           Portugal      Y
# 3           Portugal      Y
# 4           Portugal      Y
# ...              ...    ...
# 66980      Australia      Y
# 66981  United States      Y
# 66982  United States      Y
# 66983  United States      Y
# 66984  United States      Y
#
# [66985 rows x 19 columns]

# %% [markdown]
# We can also specify that we want to retain only certain columns in the `SELECT` clause:

# %%
pd.read_sql('''

SELECT r.airline AS r_airline, r.source AS departing, r.dest AS destination, r.stops, al.name AS airline
FROM routes AS r
    INNER JOIN airlines AS al
        ON r.airline_id = al.id
''', conn)
# Out:
#       r_airline departing destination stops           airline
# 0            2B       AER         KZN     0        Aerocondor
# 1            2B       ASF         KZN     0        Aerocondor
# 2            2B       ASF         MRV     0        Aerocondor
# 3            2B       CEK         KZN     0        Aerocondor
# 4            2B       CEK         OVB     0        Aerocondor
# ...         ...       ...         ...   ...               ...
# 66980        ZL       WYA         ADL     0  Regional Express
# 66981        ZM       DME         FRU     0        Apache Air
# 66982        ZM       FRU         DME     0        Apache Air
# 66983        ZM       FRU         OSS     0        Apache Air
# 66984        ZM       OSS         FRU     0        Apache Air
#
# [66985 rows x 5 columns]

# %% [markdown]
# #### Note: Losing Data with Inner Joins

# %% [markdown]
# Since data rows are kept only if _both_ tables have the key, some data can be lost

# %%
df_all_routes = pd.read_sql('''
    SELECT 
        *
    FROM
        routes
''', conn)

df_routes_after_join = pd.read_sql('''
    SELECT 
        *
    FROM
        routes
        INNER JOIN airlines
            ON routes.airline_id = airlines.id
''', conn)

# %%
# Look at how the number of rows are different
df_all_routes.shape, df_routes_after_join.shape
# Out:
# ((67663, 10), (66985, 19))

# %% [markdown]
# If you want to keep your data from at least one of your tables, you should use a left join instead of an inner join.

# %% [markdown]
# ## `LEFT JOIN`

# %% [markdown]
# > A **left join** will join two tables together and but will keep all data from the first (left) table using the key provided.

# %% [markdown]
# ![](images/left_join.png)

# %% [markdown]
# Example of a left and right join:
#
# ```sql
# SELECT
#     table1.column_name,
#     table2.different_column_name
# FROM
#     table1
#     LEFT JOIN table2
#         ON table1.shared_column_name = table2.shared_column_name
# ```

# %% [markdown]
# ### Code Example for Left Join

# %% [markdown]
# Recall our example using an inner join and how it lost some data since the key wasn't in both the `routes` _and_ `airlines` tables.

# %%
df_all_routes = pd.read_sql('''
    SELECT 
        *
    FROM
        routes
''', conn)

# This will lose some data (some routes not included)
df_routes_after_inner_join = pd.read_sql('''
    SELECT 
        *
    FROM
        routes
        JOIN airlines
            ON routes.airline_id = airlines.id
''', conn)

# The number of rows are different
df_all_routes.shape, df_routes_after_inner_join.shape
# Out:
# ((67663, 10), (66985, 19))

# %% [markdown]
# If wanted to ensure we always had every route even if the key in `airlines` was not found, we could replace our `INNER JOIN` with a `LEFT JOIN`:

# %%
# This will include all the data from routes
df_routes_after_left_join = pd.read_sql('''
    SELECT 
        *
    FROM
        routes
        LEFT JOIN airlines
            ON routes.airline_id = airlines.id
''', conn)

df_all_routes.shape, df_routes_after_left_join.shape
# Out:
# ((67663, 10), (67663, 19))

# %%
df_all_routes.isna().sum()
# Out:
# index             0
# airline           0
# airline_id        0
# source            0
# source_id         0
# dest              0
# dest_id           0
# codeshare     53066
# stops             0
# equipment        18
# dtype: int64

# %%
df_routes_after_left_join.isna().sum()
# Out:
# index             0
# airline           0
# airline_id        0
# source            0
# source_id         0
# dest              0
# dest_id           0
# codeshare     53066
# stops             0
# equipment        18
# index           678
# id              678
# name            678
# alias          4040
# iata            787
# icao            841
# callsign       3860
# country         678
# active          678
# dtype: int64

# %%
# This will include all the data from routes
df_routes_after_left_join = pd.read_sql('''
    SELECT 
        *
    FROM
        airlines
        LEFT JOIN routes
            ON routes.airline_id = airlines.id
''', conn)

df_all_routes.shape, df_routes_after_left_join.shape
# Out:
# ((67663, 10), (72493, 19))

# %% [markdown]
# SQLlite will default to an **INNER JOIN** if not specified

# %% [markdown]
# ## Exercise: Joins

# %% [markdown]
# Which airline has the most routes listed in our database?

# %%
# Your code here (BEST WAY USING INNER)
pd.read_sql("""

SELECT COUNT() AS num_routes, al.name, r.airline
FROM airlines AS al
    INNER JOIN routes AS r
        ON r.airline_id = al.id
GROUP BY r.airline_id
ORDER BY num_routes DESC

""", conn)
# Out:
#      num_routes                               name airline
# 0          2484                            Ryanair      FR
# 1          2354                  American Airlines      AA
# 2          2180                    United Airlines      UA
# 3          1981                    Delta Air Lines      DL
# 4          1960                         US Airways      US
# ..          ...                                ...     ...
# 535           2  Papillon Grand Canyon Helicopters      HI
# 536           2                 SmartLynx Airlines      6Y
# 537           2             Alaska Central Express      KO
# 538           2                         Air Europe      PE
# 539           1                          Eurowings      EW
#
# [540 rows x 3 columns]

# %%
# Your code here
pd.read_sql("""

SELECT COUNT() AS num_routes, al.name, r.airline
FROM routes AS r
    LEFT JOIN airlines AS al
        ON al.id = r.airline_id
GROUP BY al.id
ORDER BY num_routes DESC

""", conn)
# Out:
#      num_routes                               name airline
# 0          2484                            Ryanair      FR
# 1          2354                  American Airlines      AA
# 2          2180                    United Airlines      UA
# 3          1981                    Delta Air Lines      DL
# 4          1960                         US Airways      US
# ..          ...                                ...     ...
# 536           2  Papillon Grand Canyon Helicopters      HI
# 537           2                 SmartLynx Airlines      6Y
# 538           2             Alaska Central Express      KO
# 539           2                         Air Europe      PE
# 540           1                          Eurowings      EW
#
# [541 rows x 3 columns]

# %%
# Your code here
pd.read_sql("""

SELECT COUNT() AS num_routes, al.name, r.airline, r.airline_id
FROM airlines AS al
    LEFT JOIN routes AS r
        ON r.airline_id = al.id
GROUP BY r.airline_id
ORDER BY num_routes DESC

""", conn)
# Out:
#      num_routes                               name airline airline_id
# 0          5508                     Private flight    None       None
# 1          2484                            Ryanair      FR       4296
# 2          2354                  American Airlines      AA         24
# 3          2180                    United Airlines      UA       5209
# 4          1981                    Delta Air Lines      DL       2009
# ..          ...                                ...     ...        ...
# 536           2  Papillon Grand Canyon Helicopters      HI      16625
# 537           2                 SmartLynx Airlines      6Y      11814
# 538           2             Alaska Central Express      KO        109
# 539           2                         Air Europe      PE        106
# 540           1                          Eurowings      EW       2260
#
# [541 rows x 4 columns]

# %%
# Your code here
df = pd.read_sql("""

SELECT al.name, al.id, r.airline, r.airline_id 
FROM airlines AS al
    LEFT JOIN routes AS r
        ON al.id = r.airline_id

""", conn)

# %%
df
# Out:
#                                                name     id airline airline_id
# 0                                    Private flight      1    None       None
# 1                                       135 Airways      2    None       None
# 2                                     1Time Airline      3    None       None
# 3      2 Sqn No 1 Elementary Flying Training School      4    None       None
# 4                                   213 Flight Unit      5    None       None
# ...                                             ...    ...     ...        ...
# 72488                                    Vuela Cuba  19828    None       None
# 72489                                 All Australia  19830    None       None
# 72490                                    Fly Europa  19831    None       None
# 72491                                   FlyPortugal  19834    None       None
# 72492                          FTI Fluggesellschaft  19845    None       None
#
# [72493 rows x 4 columns]

# %%
df['airline_id'].isna().sum()
# Out:
# 5508

# %%
# Your code here
pd.read_sql("""

SELECT al.name, r.airline, r.airline_id, al.id
FROM routes AS r
    LEFT JOIN airlines AS al
        ON r.airline_id = al.id

""", conn)
# Out:
#                    name airline airline_id     id
# 0            Aerocondor      2B        410    410
# 1            Aerocondor      2B        410    410
# 2            Aerocondor      2B        410    410
# 3            Aerocondor      2B        410    410
# 4            Aerocondor      2B        410    410
# ...                 ...     ...        ...    ...
# 67658  Regional Express      ZL       4178   4178
# 67659        Apache Air      ZM      19016  19016
# 67660        Apache Air      ZM      19016  19016
# 67661        Apache Air      ZM      19016  19016
# 67662        Apache Air      ZM      19016  19016
#
# [67663 rows x 4 columns]

# %% [markdown]
# <details>
#     <summary><b>Possible Solution</b></summary>
#
# ```sql
# SELECT
#     airlines.name AS airline,
#     COUNT() AS number_of_routes
# -- We first need to get all the relevant info via a join
# FROM
#     routes
#     -- LEFT JOIN since we want all routes (even if airline id is unknown)
#     LEFT JOIN airlines
#         ON routes.airline_id = airlines.id
# -- We need to group by airline's ID
# GROUP BY
#     airlines.id
# ORDER BY
#     number_of_routes DESC
# ```
# </details>

# %% [markdown]
# # Level Up: Execution Order

# %% [markdown]
# ```SQL
# SELECT
#     COUNT(table2.col2) AS my_new_count
#     ,table1.col2
# FROM
#     table1
#     JOIN table2
#         ON table1.col1 = table2.col2
# WHERE
#     table1.col1 > 0
# GROUP BY
#     table2.col1
# ```

# %% [markdown]
# 1. `From`
# 2. `Where`
# 3. `Group By`
# 4. `Having`
# 5. `Select`
# 6. `Order By`
# 7. `Limit`

# %%
pd.read_sql("""

SELECT
FROM 
WHERE 
GROUP BY
HAVING 
ORDER BY
LIMIT 

""")

# %%
# DOES NOT LIKE THIS AT ALL....
pd.read_sql("""

FROM routes AS r
    LEFT JOIN airlines AS al
        ON r.airline_id = al.id
GROUP BY r.airline_id
SELECT COUNT() AS num_routes, al.name, r.airline
ORDER BY num_routes DESC
LIMIT 1


""", conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: near "FROM": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-114-a1844197adec> in <module>
#       1 # DOES NOT LIKE THIS AT ALL....
# ----> 2 pd.read_sql("""
#       3
#       4 FROM routes AS r
#       5     LEFT JOIN airlines AS al
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql '
#
# FROM routes AS r
#     LEFT JOIN airlines AS al
#         ON r.airline_id = al.id
# GROUP BY r.airline_id
# SELECT COUNT() AS num_routes, al.name, r.airline
# ORDER BY num_routes DESC
# LIMIT 1
#
#
# ': near "FROM": syntax error

# %%
df_airlines = pd.read_sql("""

SELECT * 
FROM airlines


""", conn)

# %%
df_routes = pd.read_sql("""

SELECT * 
FROM routes


""", conn)

# %%
df_routes.join(df_airlines)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-270a0a20f877> in <module>
# ----> 1 df_routes.join(df_airlines)
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7868         5  K5  A5  NaN
#    7869         """
# -> 7870         return self._join_compat(
#    7871             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7872         )
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7884
#    7885         if isinstance(other, DataFrame):
# -> 7886             return merge(
#    7887                 self,
#    7888                 other,
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     668         join_index, left_indexer, right_indexer = self._get_join_info()
#     669
# --> 670         llabels, rlabels = _items_overlap_with_suffix(
#     671             self.left._info_axis, self.right._info_axis, self.suffixes
#     672         )
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2089
#    2090     if not lsuffix and not rsuffix:
# -> 2091         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2092
#    2093     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['index'], dtype='object')

# %%
df_routes.merge(df_airlines, left_on='airline_id', right_on='id')
# Out:
#        index_x airline airline_id source source_id dest dest_id codeshare  \
# 0            0      2B        410    AER      2965  KZN    2990      None
# 1            1      2B        410    ASF      2966  KZN    2990      None
# 2            2      2B        410    ASF      2966  MRV    2962      None
# 3            3      2B        410    CEK      2968  KZN    2990      None
# 4            4      2B        410    CEK      2968  OVB    4078      None
# ...        ...     ...        ...    ...       ...  ...     ...       ...
# 66980    67658      ZL       4178    WYA      6334  ADL    3341      None
# 66981    67659      ZM      19016    DME      4029  FRU    2912      None
# 66982    67660      ZM      19016    FRU      2912  DME    4029      None
# 66983    67661      ZM      19016    FRU      2912  OSS    2913      None
# 66984    67662      ZM      19016    OSS      2913  FRU    2912      None
#
#       stops equipment  index_y     id              name   alias iata icao  \
# 0         0       CR2      409    410        Aerocondor      \N   2B  ARD
# 1         0       CR2      409    410        Aerocondor      \N   2B  ARD
# 2         0       CR2      409    410        Aerocondor      \N   2B  ARD
# 3         0       CR2      409    410        Aerocondor      \N   2B  ARD
# 4         0       CR2      409    410        Aerocondor      \N   2B  ARD
# ...     ...       ...      ...    ...               ...     ...  ...  ...
# 66980     0       SF3     4171   4178  Regional Express      \N   ZL  RXA
# 66981     0       734     5977  19016        Apache Air  Apache   ZM  IWA
# 66982     0       734     5977  19016        Apache Air  Apache   ZM  IWA
# 66983     0       734     5977  19016        Apache Air  Apache   ZM  IWA
# 66984     0       734     5977  19016        Apache Air  Apache   ZM  IWA
#
#          callsign        country active
# 0      AEROCONDOR       Portugal      Y
# 1      AEROCONDOR       Portugal      Y
# 2      AEROCONDOR       Portugal      Y
# 3      AEROCONDOR       Portugal      Y
# 4      AEROCONDOR       Portugal      Y
# ...           ...            ...    ...
# 66980         REX      Australia      Y
# 66981      APACHE  United States      Y
# 66982      APACHE  United States      Y
# 66983      APACHE  United States      Y
# 66984      APACHE  United States      Y
#
# [66985 rows x 19 columns]
